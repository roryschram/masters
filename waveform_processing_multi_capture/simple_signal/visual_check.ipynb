# %%
# %matplotlib widget
import numpy as np
# import matplotlib
# matplotlib.use("TkAgg")
import matplotlib.pyplot as plt
from matplotlib.axis import Axis


fig, axs = plt.subplots(1,1)

for i in range(1,51,1):
    input = np.load("../../masters_large_data/received_data/multi_receive/channel_estimations/channel_est"+str(i)+".npy")
    axs.plot(input,color='blue')

for i in range(51,101,1):
    input = np.load("../../masters_large_data/received_data/multi_receive/channel_estimations/channel_est"+str(i)+".npy")
    axs.plot(input,color='orange')
axs.set_ybound(0.0,1.1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 12
#       9 fig, axs = plt.subplots(1,1)
#      11 for i in range(1,51,1):
# ---> 12     input = np.load("../masters_large_data/received_data/multi_receive/channel_estimations/channel_est"+str(i)+".npy")
#      13     axs.plot(input,color='blue')
#      15 for i in range(51,101,1):
#
# File ~/Desktop/masters/.venv/lib/python3.12/site-packages/numpy/lib/_npyio_impl.py:451, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     449     own_fid = False
#     450 else:
# --> 451     fid = stack.enter_context(open(os.fspath(file), "rb"))
#     452     own_fid = True
#     454 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: '../masters_large_data/received_data/multi_receive/channel_estimations/channel_est1.npy'
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
